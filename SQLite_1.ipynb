# %% [markdown]
# <a href="https://colab.research.google.com/github/mcgmed/SQL/blob/main/SQLite_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
con = sqlite3.connect('/content/sample_data/chinook.db')
cur = con.cursor()

# %%
res = cur.execute('SELECT name FROM sqlite_master') # to see all the table names in the dataset.
res.fetchall()
# Out:
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('sqlite_autoindex_playlist_track_1',),
#  ('tracks',),
#  ('IFK_AlbumArtistId',),
#  ('IFK_CustomerSupportRepId',),
#  ('IFK_EmployeeReportsTo',),
#  ('IFK_InvoiceCustomerId',),
#  ('IFK_InvoiceLineInvoiceId',),
#  ('IFK_InvoiceLineTrackId',),
#  ('IFK_PlaylistTrackTrackId',),
#  ('IFK_TrackAlbumId',),
#  ('IFK_TrackGenreId',),
#  ('IFK_TrackMediaTypeId',),
#  ('sqlite_stat1',)]

# %%
res = cur.execute('PRAGMA table_info(albums)') # to see all the column names and specifications in the table.
res.fetchall()
# Out:
# [(0, 'AlbumId', 'INTEGER', 1, None, 1),
#  (1, 'Title', 'NVARCHAR(160)', 1, None, 0),
#  (2, 'ArtistId', 'INTEGER', 1, None, 0)]

# %%
res = cur.execute('SELECT * FROM albums') # now this is the query time.
res.fetchall()
# Out:
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (7, 'Facelift', 5),
#  (8, 'Warner 25 Anos', 6),
#  (9, 'Plays Metallica By Four Cellos', 7),
#  (10, 'Audioslave', 8),
#  (11, 'Out Of Exile', 8),
#  (12, 'BackBeat Soundtrack', 9),
#  (13, 'The Best Of Billy Cobham', 10),
#  (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11),
#  (15, 'Alcohol Fueled Brewtality Live! [Disc 2]', 11),
#  (16, 'Black Sabbath', 12),
#  (17, 'Black Sabbath Vol. 4 (Remaster)', 12),
#  (18, 'Body Count', 13),
#  (19, 'Chemical Wedding', 14),
#  (20, 'The Best Of Buddy Guy - The Millenium Collection', 15),
#  (21, 'Prenda Minha', 16),
#  (22, 'Sozinho Remix Ao Vivo', 16),
#  (23, 'Minha Historia', 17),
#  (24, 'Afrociberdelia', 18),
#  (25, 'Da Lama Ao Caos', 18),
#  (26, 'Acústico MTV [Live]', 19),
#  (27, 'Cidade Negra - Hits', 19),
# ...

# %% [markdown]
# ## SELECT

# %%
query = 'SELECT * FROM albums'
data = pd.read_sql(query, con)
data
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %% [markdown]
# You should use the asterisk (*) for the testing purpose only, not in the real application development.
#
# Because when you develop an application, you should control what SQLite returns to your application. Suppose, a table has 3 columns, and you use the asterisk (*) to retrieve the data from all three columns. What if someone removes a column, your application would not be working properly, because it assumes that there are three columns returned and the logic to process those three columns would be broken. If someone adds more columns, your application may work but it gets more data than needed, which creates more I/O overhead between the database and application. So try to avoid using the asterisk as a good habit when you use the SELECT statement.

# %%
query = 'SELECT trackid, name, composer, unitprice FROM tracks'
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                               Name  \
# 0           1            For Those About To Rock (We Salute You)
# 1           2                                  Balls to the Wall
# 2           3                                    Fast As a Shark
# 3           4                                  Restless and Wild
# 4           5                               Princess of the Dawn
# ...       ...                                                ...
# 3498     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3499     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3500     3501               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3501     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3502     3503                                      Koyaanisqatsi
#
#                                                Composer  UnitPrice
# 0             Angus Young, Malcolm Young, Brian Johnson       0.99
# ...

# %% [markdown]
# ## ORDER BY

# %%
query = 'SELECT name, milliseconds, albumid FROM tracks ORDER BY albumid ASC'
data = pd.read_sql(query, con)
data
# Out:
#                                                    Name  Milliseconds  AlbumId
# 0               For Those About To Rock (We Salute You)        343719        1
# 1                                 Put The Finger On You        205662        1
# 2                                       Let's Get It Up        233926        1
# 3                                      Inject The Venom        210834        1
# 4                                            Snowballed        203102        1
# ...                                                 ...           ...      ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...        286741      343
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...        139200      344
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)         66639      345
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...        221331      346
# 3502                                      Koyaanisqatsi        206005      347
#
# [3503 rows x 3 columns]

# %% [markdown]
# SQLite uses ASC by default.

# %% [markdown]
# Suppose you want to sort the sorted result (by AlbumId) above by the Milliseconds column in descending order:

# %%
query = 'SELECT name, milliseconds, albumid FROM tracks ORDER BY albumid ASC, milliseconds DESC'
data = pd.read_sql(query, con)
data
# Out:
#                                                    Name  Milliseconds  AlbumId
# 0               For Those About To Rock (We Salute You)        343719        1
# 1                                            Spellbound        270863        1
# 2                                            Evil Walks        263497        1
# 3                                    Breaking The Rules        263288        1
# 4                                       Let's Get It Up        233926        1
# ...                                                 ...           ...      ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...        286741      343
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...        139200      344
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)         66639      345
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...        221331      346
# 3502                                      Koyaanisqatsi        206005      347
#
# [3503 rows x 3 columns]

# %% [markdown]
# Instead of specifying the names of columns, you can use the column’s position in the ORDER BY clause. For example, the following statement sorts the tracks by both albumid (3rd column) and milliseconds (2nd column) in ascending order:

# %%
query = 'SELECT name, milliseconds, albumid FROM tracks ORDER BY 3, 2 DESC'
data = pd.read_sql(query, con)
data
# Out:
#                                                    Name  Milliseconds  AlbumId
# 0               For Those About To Rock (We Salute You)        343719        1
# 1                                            Spellbound        270863        1
# 2                                            Evil Walks        263497        1
# 3                                    Breaking The Rules        263288        1
# 4                                       Let's Get It Up        233926        1
# ...                                                 ...           ...      ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...        286741      343
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...        139200      344
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)         66639      345
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...        221331      346
# 3502                                      Koyaanisqatsi        206005      347
#
# [3503 rows x 3 columns]

# %% [markdown]
# Looking for NULL values:

# %%
query = 'SELECT trackid, name, Composer FROM tracks ORDER BY Composer'
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                   Name      Composer
# 0           2                      Balls to the Wall          None
# 1          63                             Desafinado          None
# 2          64                      Garota De Ipanema          None
# 3          65  Samba De Uma Nota Só (One Note Samba)          None
# 4          66                      Por Causa De Você          None
# ...       ...                                    ...           ...
# 3498      820                           Time To Kill  roger glover
# 3499      821                         Ramshackle Man  roger glover
# 3500      822                    A Twist In The Tail  roger glover
# 3501      824                              Solitaire  roger glover
# 3502      825                         One Man's Meat  roger glover
#
# [3503 rows x 3 columns]

# %% [markdown]
# ## SELECT DISTINCT

# %%
query = 'SELECT city FROM customers ORDER BY city'
data = pd.read_sql(query, con)
data
# Out:
#                    City
# 0             Amsterdam
# 1             Bangalore
# 2                Berlin
# 3                Berlin
# 4              Bordeaux
# 5                Boston
# 6              Brasília
# 7              Brussels
# 8              Budapest
# 9          Buenos Aires
# 10              Chicago
# 11           Copenhagen
# 12            Cupertino
# 13                Delhi
# 14                Dijon
# 15               Dublin
# 16           Edinburgh
# 17             Edmonton
# 18           Fort Worth
# 19            Frankfurt
# 20              Halifax
# 21             Helsinki
# 22               Lisbon
# 23               London
# 24               London
# 25                 Lyon
# 26              Madison
# 27               Madrid
# 28             Montréal
# 29        Mountain View
# 30        Mountain View
# 31             New York
# 32              Orlando
# 33                 Oslo
# 34               Ottawa
# 35                Paris
# 36                Paris
# ...

# %%
query = 'SELECT DISTINCT city FROM customers ORDER BY city'
data = pd.read_sql(query, con)
data
# Out:
#                    City
# 0             Amsterdam
# 1             Bangalore
# 2                Berlin
# 3              Bordeaux
# 4                Boston
# 5              Brasília
# 6              Brussels
# 7              Budapest
# 8          Buenos Aires
# 9               Chicago
# 10           Copenhagen
# 11            Cupertino
# 12                Delhi
# 13                Dijon
# 14               Dublin
# 15           Edinburgh
# 16             Edmonton
# 17           Fort Worth
# 18            Frankfurt
# 19              Halifax
# 20             Helsinki
# 21               Lisbon
# 22               London
# 23                 Lyon
# 24              Madison
# 25               Madrid
# 26             Montréal
# 27        Mountain View
# 28             New York
# 29              Orlando
# 30                 Oslo
# 31               Ottawa
# 32                Paris
# 33                Porto
# 34               Prague
# 35              Redmond
# 36                 Reno
# ...

# %% [markdown]
# To remove duplicate the city and country, you apply the DISTINCT clause to both city and country columns as shown in the following query:

# %%
query = 'SELECT DISTINCT city, country FROM customers ORDER BY country'
data = pd.read_sql(query, con)
data
# Out:
#                    City         Country
# 0          Buenos Aires       Argentina
# 1                Sidney       Australia
# 2                Vienne         Austria
# 3              Brussels         Belgium
# 4   São José dos Campos          Brazil
# 5             São Paulo          Brazil
# 6        Rio de Janeiro          Brazil
# 7              Brasília          Brazil
# 8              Montréal          Canada
# 9              Edmonton          Canada
# 10            Vancouver          Canada
# 11              Toronto          Canada
# 12               Ottawa          Canada
# 13              Halifax          Canada
# 14             Winnipeg          Canada
# 15          Yellowknife          Canada
# 16             Santiago           Chile
# 17               Prague  Czech Republic
# 18           Copenhagen         Denmark
# 19             Helsinki         Finland
# 20                Paris          France
# 21                 Lyon          France
# ...

# %% [markdown]
# ## WHERE

# %%
query = 'SELECT name, milliseconds, bytes, albumid FROM tracks WHERE albumid=1'
data = pd.read_sql(query, con)
data
# Out:
#                                       Name  Milliseconds     Bytes  AlbumId
# 0  For Those About To Rock (We Salute You)        343719  11170334        1
# 1                    Put The Finger On You        205662   6713451        1
# 2                          Let's Get It Up        233926   7636561        1
# 3                         Inject The Venom        210834   6852860        1
# 4                               Snowballed        203102   6599424        1
# 5                               Evil Walks        263497   8611245        1
# 6                                   C.O.D.        199836   6566314        1
# 7                       Breaking The Rules        263288   8596840        1
# 8                 Night Of The Long Knives        205688   6706347        1
# 9                               Spellbound        270863   8817038        1

# %%
query = 'SELECT name, milliseconds, bytes, albumid FROM tracks WHERE albumid=1 AND milliseconds > 250000'
data = pd.read_sql(query, con)
data
# Out:
#                                       Name  Milliseconds     Bytes  AlbumId
# 0  For Those About To Rock (We Salute You)        343719  11170334        1
# 1                               Evil Walks        263497   8611245        1
# 2                       Breaking The Rules        263288   8596840        1
# 3                               Spellbound        270863   8817038        1

# %% [markdown]
# ## WHERE + LIKE

# %%
query = "SELECT name, albumid, composer FROM tracks WHERE composer LIKE '%Smith%' ORDER BY albumid"
data = pd.read_sql(query, con)
data
# Out:
#                      Name  AlbumId  \
# 0       Restless and Wild        3
# 1    Princess of the Dawn        3
# 2           Killing Floor       19
# 3             Machine Men       19
# 4   2 Minutes To Midnight       95
# ..                    ...      ...
# 92                 Savior      195
# 93       Dancing Barefoot      234
# 94           Take the Box      322
# 95   What Is It About Men      322
# 96    Amy Amy Amy (Outro)      322
#
#                                              Composer
# 0   F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...
# 1                          Deaffy & R.A. Smith-Diesel
# 2                                        Adrian Smith
# 3                                        Adrian Smith
# 4                        Adrian Smith/Bruce Dickinson
# ..                                                ...
# 92     Anthony Kiedis/Chad Smith/Flea/John Frusciante
# 93                              Ivan Kral/Patti Smith
# ...

# %% [markdown]
# ## WHERE + IN

# %%
query = "SELECT name, albumid, mediatypeid FROM tracks WHERE mediatypeid IN (2, 3)"
data = pd.read_sql(query, con)
data
# Out:
#                                                Name  AlbumId  MediaTypeId
# 0                                 Balls to the Wall        2            2
# 1                                   Fast As a Shark        3            2
# 2                                 Restless and Wild        3            2
# 3                              Princess of the Dawn        3            2
# 4                             Welcome to the Jungle       90            2
# ..                                              ...      ...          ...
# 446               There's No Place Like Home, Pt. 2      261            3
# 447               There's No Place Like Home, Pt. 3      261            3
# 448  Band Members Discuss Tracks from "Revelations"      271            3
# 449                                  Branch Closing      251            3
# 450                                      The Return      251            3
#
# [451 rows x 3 columns]

# %% [markdown]
# ## LIMIT

# %%
query = "SELECT trackId, name FROM tracks LIMIT 10" # It gives the ten rows from data
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                                     Name
# 0        1  For Those About To Rock (We Salute You)
# 1        2                        Balls to the Wall
# 2        3                          Fast As a Shark
# 3        4                        Restless and Wild
# 4        5                     Princess of the Dawn
# 5        6                    Put The Finger On You
# 6        7                          Let's Get It Up
# 7        8                         Inject The Venom
# 8        9                               Snowballed
# 9       10                               Evil Walks

# %% [markdown]
# If you want to get the first 10 rows starting from the 10th row of the result set, you use OFFSET keyword as the following:

# %%
query = "SELECT trackId, name FROM tracks LIMIT 10 OFFSET 10" # It gives the ten rows from data
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                      Name
# 0       11                    C.O.D.
# 1       12        Breaking The Rules
# 2       13  Night Of The Long Knives
# 3       14                Spellbound
# 4       15                   Go Down
# 5       16               Dog Eat Dog
# 6       17         Let There Be Rock
# 7       18            Bad Boy Boogie
# 8       19             Problem Child
# 9       20                  Overdose

# %% [markdown]
# The ORDER BY clause appears before the LIMIT clause in the SELECT statement. SQLite sorts the result set before getting the number of rows specified in the LIMIT clause.

# %%
query = "SELECT trackId, name, bytes FROM tracks ORDER BY bytes DESC LIMIT 10"
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                         Name       Bytes
# 0     3224      Through a Looking Glass  1059546140
# 1     2820       Occupation / Precipice  1054423946
# 2     3236              The Young Lords   587051735
# 3     3242      The Man With Nine Lives   577829804
# 4     2910                         Dave   574325829
# 5     3235     The Magnificent Warriors   570152232
# 6     3231             The Lost Warrior   558872190
# 7     2902              Maternity Leave   555244214
# 8     3228  Battlestar Galactica, Pt. 3   554509033
# 9     2832               The Woman King   552893447

# %%
query = "SELECT trackId, name, milliseconds FROM tracks ORDER BY milliseconds ASC LIMIT 5"
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                      Name  Milliseconds
# 0     2461  É Uma Partida De Futebol          1071
# 1      168                Now Sports          4884
# 2      170               A Statistic          6373
# 3      178                     Oprah          6635
# 4     3304              Commercial 1          7941

# %% [markdown]
# ## BETWEEN

# %%
query = "SELECT InvoiceId, BillingAddress, Total FROM invoices WHERE Total BETWEEN 14.91 AND 18.86"
data = pd.read_sql(query, con)
data
# Out:
#    InvoiceId                        BillingAddress  Total
# 0         88                       Calle Lira, 198  17.91
# 1         89  Rotenturmstraße 4, 1010 Innere Stadt  18.86
# 2        103                 162 E Superior Street  15.86
# 3        193                      Berger Straße 10  14.91
# 4        201                 319 N. Frances Street  18.86
# 5        208                      Ullevålsveien 14  15.86
# 6        306                         Klanova 9/506  16.86
# 7        313                      68, Rue Jouvence  16.86

# %%
query = "SELECT InvoiceId, BillingAddress, Total FROM invoices WHERE Total NOT BETWEEN 1 AND 20 ORDER BY Total"
data = pd.read_sql(query, con)
data
# Out:
#     InvoiceId                            BillingAddress  Total
# 0           6                          Berger Straße 10   0.99
# 1          13                 1600 Amphitheatre Parkway   0.99
# 2          20                            110 Raeburn Pl   0.99
# 3          27                            5112 48 Street   0.99
# 4          34                          Praça Pio X, 119   0.99
# 5          41                        C/ San Bernardo 85   0.99
# 6          48                    796 Dundas Street West   0.99
# 7          55                           Grétrystraat 63   0.99
# 8          62                          3 Chatham Street   0.99
# 9          69                     319 N. Frances Street   0.99
# 10         76                          Ullevålsveien 14   0.99
# 11         83                    9, Place Louis Barthou   0.99
# 12         90                          801 W 4th Street   0.99
# 13        104                       Barbarossastraße 19   0.99
# ...

# %%
query = '''SELECT InvoiceId, BillingAddress, InvoiceDate, Total
           FROM invoices
           WHERE InvoiceDate BETWEEN '2010-01-01' AND '2010-01-31'
           ORDER BY InvoiceDate'''
data = pd.read_sql(query, con)
data
# Out:
#    InvoiceId                        BillingAddress          InvoiceDate  Total
# 0         84                      68, Rue Jouvence  2010-01-08 00:00:00   1.98
# 1         85                     Erzsébet krt. 58.  2010-01-08 00:00:00   1.98
# 2         86                Via Degli Scipioni, 43  2010-01-09 00:00:00   3.96
# 3         87                           Celsiusg. 9  2010-01-10 00:00:00   6.94
# 4         88                       Calle Lira, 198  2010-01-13 00:00:00  17.91
# 5         89  Rotenturmstraße 4, 1010 Innere Stadt  2010-01-18 00:00:00  18.86
# 6         90                      801 W 4th Street  2010-01-26 00:00:00   0.99

# %%
query = '''SELECT InvoiceId, BillingAddress, InvoiceDate, Total
           FROM invoices
           WHERE InvoiceDate NOT BETWEEN '2009-01-03' AND '2013-12-01'
           ORDER BY InvoiceDate'''
data = pd.read_sql(query, con)
data
# Out:
#    InvoiceId                            BillingAddress          InvoiceDate  \
# 0          1                   Theodor-Heuss-Straße 34  2009-01-01 00:00:00
# 1          2                          Ullevålsveien 14  2009-01-02 00:00:00
# 2        406                          801 W 4th Street  2013-12-04 00:00:00
# 3        407                           69 Salem Street  2013-12-04 00:00:00
# 4        408                     319 N. Frances Street  2013-12-05 00:00:00
# 5        409                    796 Dundas Street West  2013-12-06 00:00:00
# 6        410  Rua dos Campeões Europeus de Viena, 4350  2013-12-09 00:00:00
# 7        411                           Porthaninkatu 9  2013-12-14 00:00:00
# 8        412                       12,Community Centre  2013-12-22 00:00:00
#
#    Total
# 0   1.98
# 1   3.96
# 2   1.98
# 3   1.98
# 4   3.96
# 5   5.94
# 6   8.91
# 7  13.86
# 8   1.99

# %% [markdown]
# ## IN

# %% [markdown]
# The SQLite IN operator determines whether a value matches any value in a list or a subquery.

# %%
query = '''SELECT TrackID, Name, Mediatypeid
           FROM Tracks
           WHERE MediaTypeId IN (1, 2)'''
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                               Name  MediaTypeId
# 0           1            For Those About To Rock (We Salute You)            1
# 1           6                              Put The Finger On You            1
# 2           7                                    Let's Get It Up            1
# 3           8                                   Inject The Venom            1
# 4           9                                         Snowballed            1
# ...       ...                                                ...          ...
# 3266     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...            2
# 3267     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...            2
# 3268     3501               L'orfeo, Act 3, Sinfonia (Orchestra)            2
# 3269     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...            2
# 3270     3503                                      Koyaanisqatsi            2
#
# [3271 rows x 3 columns]

# %% [markdown]
# And this is the same as above:

# %%
query = '''SELECT TrackID, Name, Mediatypeid
           FROM Tracks
           WHERE MediaTypeId = 1 OR MediaTypeId = 2'''
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                               Name  MediaTypeId
# 0           1            For Those About To Rock (We Salute You)            1
# 1           6                              Put The Finger On You            1
# 2           7                                    Let's Get It Up            1
# 3           8                                   Inject The Venom            1
# 4           9                                         Snowballed            1
# ...       ...                                                ...          ...
# 3266     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...            2
# 3267     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...            2
# 3268     3501               L'orfeo, Act 3, Sinfonia (Orchestra)            2
# 3269     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...            2
# 3270     3503                                      Koyaanisqatsi            2
#
# [3271 rows x 3 columns]

# %%
query = '''SELECT albumid
           FROM albums
           WHERE artistid = 12'''
data = pd.read_sql(query, con)
data
# Out:
#    AlbumId
# 0       16
# 1       17

# %% [markdown]
# And this one with subquery is the same as above:

# %%
query = '''SELECT albumid
           FROM albums
           WHERE AlbumId IN (SELECT	AlbumId	FROM Albums WHERE	ArtistId = 12)'''
data = pd.read_sql(query, con)
data
# Out:
#    AlbumId
# 0       16
# 1       17

# %%
query = '''SELECT trackid, name, genreid
           FROM tracks
           WHERE genreid NOT IN (1, 2, 3)'''
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                               Name  GenreId
# 0          99                                 Your Time Has Come        4
# 1         100                                       Out Of Exile        4
# 2         101                                        Be Yourself        4
# 3         102                                  Doesn't Remind Me        4
# 4         103                                    Drown Me Slowly        4
# ...       ...                                                ...      ...
# 1697     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...       24
# 1698     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...       24
# 1699     3501               L'orfeo, Act 3, Sinfonia (Orchestra)       24
# 1700     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...       24
# 1701     3503                                      Koyaanisqatsi       10
#
# [1702 rows x 3 columns]

# %% [markdown]
# ## LIKE

# %% [markdown]
# The s% pattern that uses the percent sign wildcard ( %) matches any string that starts with s e.g.,son and so.
#
# The %er pattern matches any string that ends with er like peter, clever, etc.
#
# And the %per% pattern matches any string that contains per such as percent and peeper.
#
# The h_nt pattern matches hunt, hint, etc. The __pple pattern matches topple, supple, tipple, etc.
#
# Note that SQLite LIKE operator is case-insensitive. It means "A" LIKE "a" is true.
#
# In case you want to make LIKE operator works case-sensitively, you need to use the following PRAGMA: PRAGMA case_sensitive_like = true;

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name LIKE 'Wild%'"""
data = pd.read_sql(query, con)
data
# Out:
#    TrackId              Name
# 0     1245    Wildest Dreams
# 1     1973         Wild Side
# 2     2627  Wild Hearted Son
# 3     2633       Wild Flower
# 4     2944        Wild Honey

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name LIKE '%Wild'"""
data = pd.read_sql(query, con)
data
# Out:
#    TrackId               Name
# 0        4  Restless and Wild
# 1       32    Deuces Are Wild
# 2      775   Call Of The Wild
# 3     2697          I Go Wild

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name LIKE '%Wild%'"""
data = pd.read_sql(query, con)
data
# Out:
#     TrackId                               Name
# 0         4                  Restless and Wild
# 1        32                    Deuces Are Wild
# 2       775                   Call Of The Wild
# 3      1245                     Wildest Dreams
# 4      1869          Where The Wild Things Are
# 5      1973                          Wild Side
# 6      2312                   Near Wild Heaven
# 7      2627                   Wild Hearted Son
# 8      2633                        Wild Flower
# 9      2697                          I Go Wild
# 10     2930  Who's Gonna Ride Your Wild Horses
# 11     2944                         Wild Honey

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name LIKE '%Br_wn%'"""
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                  Name
# 0     1053  Bad, Bad Leroy Brown
# 1     1150        Mr. Brownstone

# %% [markdown]
# If the pattern that you want to match contains % or _, you must use an escape character in an optional ESCAPE clause. When you specify the ESCAPE clause, the LIKE operator will evaluate the expression that follows the ESCAPE keyword to a string which consists of a single character, or an escape character. Then you can use this escape character in the pattern to include literal percent sign or underscore.  The LIKE operator evaluates the percent sign or underscore that follows the escape character as a literal string, not a wildcard character. Example:

# %%
query = "column_1 LIKE '%10\%%' ESCAPE '\'"

# %% [markdown]
# ## GLOB

# %% [markdown]
# The GLOB operator is similar to the LIKE operator. The GLOB operator determines whether a string matches a specific pattern. Unlike the LIKE operator, the GLOB operator is case sensitive and uses the UNIX wildcards. In addition, the GLOB patterns do not have escape characters.
#
# The following shows the wildcards used with the GLOB  operator:
#
# The asterisk (*) wildcard matches any number of characters. The question mark (?) wildcard matches exactly one character.
#
# On top of these wildcards, you can use the list wildcard [] to match one character from a list of characters. For example [xyz] match any single x, y, or z character.

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB 'Man*'"""
data = pd.read_sql(query, con)
data
# Out:
#     TrackId                                     Name
# 0        52                           Man In The Box
# 1       106                            Man Or Animal
# 2       257                               Manguetown
# 3       358                  Man With The Woman Head
# 4       562                                Mangueira
# 5       584                                   Manuel
# 6      1397                          Man On The Edge
# 7      1459                         Manifest Destiny
# 8      1480                         Manic Depression
# 9      2046                               Manguetown
# 10     2859  Man of Science, Man of Faith (Premiere)

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB '*Man'"""
data = pd.read_sql(query, con)
data
# Out:
#     TrackId                          Name
# 0        31                     Blind Man
# 1       359                    Muffin Man
# 2       431             The Invisible Man
# 3       760               Hard Lovin' Man
# 4       809                      Holy Man
# 5       821                Ramshackle Man
# 6       836          Make Love Like A Man
# 7       962                    Just A Man
# 8      1235                The Wicker Man
# 9      1353                The Wicker Man
# 10     1457                  Half The Man
# 11     1573                     2,000 Man
# 12     1809               Of Wolf And Man
# 13     2107                      Iron Man
# 14     2162                    Better Man
# 15     2224                    Mystic Man
# 16     2228  Equal Rights Downpresser Man
# 17     2372                 My Lovely Man
# 18     2645                 Back Door Man
# 19     2854                   Company Man
# 20     2855                   Company Man
# ...

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB '?ere*'"""
data = pd.read_sql(query, con)
data
# Out:
#    TrackId                          Name
# 0      324                        Pererê
# 1     1132                      Serenity
# 2     1452       Were Do We Go From Here
# 3     1740                        Sereia
# 4     2198                        Jeremy
# 5     2479       Here's To The Atom Bomb
# 6     2791                   Hereditário
# 7     3042  Here I Am (Come And Take Me)
# 8     3133               Here I Go Again

# %% [markdown]
# To find the tracks whose names contain numbers, you can use the list wildcard [0-9] as follows:

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB '*[1-9]*'"""
data = pd.read_sql(query, con)
data
# Out:
#      TrackId                                               Name
# 0        109                                            #1 Zero
# 1        122                                     20 Flight Rock
# 2        132                                  13 Years Of Grief
# 3        343                         Communication Breakdown(2)
# 4        347                         Communication Breakdown(3)
# ..       ...                                                ...
# 167     3497                                    Erlkonig, D.328
# 168     3498  Concerto for Violin, Strings and Continuo in G...
# 169     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 170     3501               L'orfeo, Act 3, Sinfonia (Orchestra)
# 171     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...
#
# [172 rows x 2 columns]

# %% [markdown]
# Or to find the tracks whose name does not contain any number, you place the character ^ at the beginning of the list:

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB '*[^1-9]*'"""
data = pd.read_sql(query, con)
data
# Out:
#       TrackId                                               Name
# 0           1            For Those About To Rock (We Salute You)
# 1           2                                  Balls to the Wall
# 2           3                                    Fast As a Shark
# 3           4                                  Restless and Wild
# 4           5                               Princess of the Dawn
# ...       ...                                                ...
# 3497     3499  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3498     3500  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3499     3501               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3500     3502  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3501     3503                                      Koyaanisqatsi
#
# [3502 rows x 2 columns]

# %% [markdown]
# The following statement finds the tracks whose names end with a number.

# %%
query = """SELECT trackid, name
           FROM tracks
           WHERE name GLOB '*[1-9]'"""
data = pd.read_sql(query, con)
data
# Out:
#     TrackId                                               Name
# 0       360                                       Vai-Vai 2001
# 1       361                                           X-9 2001
# 2       362                                       Gavioes 2001
# 3       363                                          Nene 2001
# 4       364                                 Rosas De Ouro 2001
# ..      ...                                                ...
# 72     3364                  There's No Place Like Home, Pt. 3
# 73     3425  Adagio for Strings from the String Quartet, Op...
# 74     3452       SCRIABIN: Prelude in B Major, Op. 11, No. 11
# 75     3479                        Prometheus Overture, Op. 43
# 76     3497                                    Erlkonig, D.328
#
# [77 rows x 2 columns]

# %% [markdown]
# ## IS NULL

# %% [markdown]
# Returns null values.

# %%
query = """SELECT name, composer
           FROM tracks
           WHERE Composer IS NULL
           ORDER BY name"""
data = pd.read_sql(query, con)
data
# Out:
#                                                 Name Composer
# 0                                                "?"     None
# 1                                           #9 Dream     None
# 2            (I Can't Help) Falling In Love With You     None
# 3                                       ...And Found     None
# 4                                  ...In Translation     None
# ..                                               ...      ...
# 973                                         Às Vezes     None
# 974                                            Álibi     None
# 975  Étude 1, In C Major - Preludio (Presto) - Liszt     None
# 976                                           Óculos     None
# 977                              Óia Eu Aqui De Novo     None
#
# [978 rows x 2 columns]

# %%
query = """SELECT name, composer
           FROM tracks
           WHERE Composer IS NOT NULL
           ORDER BY name"""
data = pd.read_sql(query, con)
data
# Out:
#                                                    Name  \
# 0                                                  "40"
# 1     "Eine Kleine Nachtmusik" Serenade In G, K. 525...
# 2                                               #1 Zero
# 3                                       'Round Midnight
# 4                            (Anesthesia) Pulling Teeth
# ...                                                 ...
# 2520                                             É Fogo
# 2521                              É Preciso Saber Viver
# 2522                           É Uma Partida De Futebol
# 2523              É que Nessa Encarnação Eu Nasci Manga
# 2524                                Último Pau-De-Arara
#
#                                 Composer
# 0                                     U2
# 1                Wolfgang Amadeus Mozart
# 2     Cornell, Commerford, Morello, Wilk
# 3                            Miles Davis
# 4                           Cliff Burton
# ...
